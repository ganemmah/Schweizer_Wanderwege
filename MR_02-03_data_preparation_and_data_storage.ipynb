# %% [markdown]
# ### 1. Setup & CSV einlesen

# %%
# -----------------------------------------------------------
# 1) Import necessary libraries
# -----------------------------------------------------------
import pandas as pd
import numpy as np
import re
import sys
# !{sys.executable} -m pip install sqlalchemy pymysql cryptography

# Import utility functions
from db_utils import setup_display_settings, write_to_db

# Setup display settings
setup_display_settings()

# -----------------------------------------------------------
# 2) Load the dataset (adjust filename if needed)
# -----------------------------------------------------------
df = pd.read_csv("schweizer_wanderwege_alle.csv")

# First quick look
df.head()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sqlalchemy in c:\users\sulri\appdata\roaming\python\python314\site-packages (2.0.45)
# Requirement already satisfied: pymysql in c:\users\sulri\appdata\roaming\python\python314\site-packages (1.1.2)
# Requirement already satisfied: cryptography in c:\users\sulri\appdata\roaming\python\python314\site-packages (46.0.3)
# Requirement already satisfied: greenlet>=1 in c:\users\sulri\appdata\roaming\python\python314\site-packages (from sqlalchemy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\sulri\appdata\roaming\python\python314\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\sulri\appdata\roaming\python\python314\site-packages (from cryptography) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\sulri\appdata\roaming\python\python314\site-packages (from cffi>=2.0.0->cryptography) (2.23)
# ✅ Display settings configured
#   web_scraper_order                              web_scraper_start_url                                         detail_url  \
# 0      1766396370-1  https://www.schweizer-wanderwege.ch/de/wanderv...  https://www.schweizer-wanderwege.ch/de/wanderv...
# 1      1766396372-2  https://www.schweizer-wanderwege.ch/de/wanderv...  https://www.schweizer-wanderwege.ch/de/wanderv...
# 2      1766396375-3  https://www.schweizer-wanderwege.ch/de/wanderv...  https://www.schweizer-wanderwege.ch/de/wanderv...
# 3      1766396377-4  https://www.schweizer-wanderwege.ch/de/wanderv...  https://www.schweizer-wanderwege.ch/de/wanderv...
# 4      1766396379-5  https://www.schweizer-wanderwege.ch/de/wanderv...  https://www.schweizer-wanderwege.ch/de/wanderv...
#
#                                         title                                           location difficulty_level  duration distance  \
# 0                                 Husky-Traum                                          Muotathal              NaN       NaN       4m
# 1  Aufregende Ausblicke auf dem Hochalp Trail  Urnäsch, Anker\n                              ...              NaN  6h 45min   11.4km
# 2                    Den ganzen Tag im Schnee  Atzmännig SSA\n                               ...              NaN  1h 40min    4.2km
# 3                  Panorama Trail in Obwalden  Langis\n                                      ...              NaN  4h 30min   12.3km
# 4      Schneeschuhwanderung auf den Chasseron  Les Rasses, village\n                         ...              NaN  4h 20min     10km
#
#   physical_demand ascent descent                                       target_group      season recommended_period
# 0            hoch    NaN     NaN  Zyklus 1 (Grundschule / 6 - 9 Jahre alt), Zykl...  ganzjährig                NaN
# 1            hoch   720m    720m                                                NaN      Winter    Dezember - März
# 2          mittel   140m    510m                                       für Familien      Winter    Dezember - März
# 3            hoch   565m    565m                                                NaN      Winter    Dezember - März
# 4            hoch   450m    450m                                                NaN      Winter    Dezember - März

# %% [markdown]
# ### 2. Remove unnecessary scraper columns

# %%
# -----------------------------------------------------------
# Remove columns created automatically by the web-scraper
# These do not contain useful analytical information
# -----------------------------------------------------------
columns_to_drop = ["web_scraper_order", "web_scraper_start_url"]

df = df.drop(columns=columns_to_drop, errors="ignore")

# Rename the "detail_url" column to a simpler name
df = df.rename(columns={"detail_url": "url"})

df.head()
# Out:
#                                                  url                                       title                                           location  \
# 0  https://www.schweizer-wanderwege.ch/de/wanderv...                                 Husky-Traum                                          Muotathal
# 1  https://www.schweizer-wanderwege.ch/de/wanderv...  Aufregende Ausblicke auf dem Hochalp Trail  Urnäsch, Anker\n                              ...
# 2  https://www.schweizer-wanderwege.ch/de/wanderv...                    Den ganzen Tag im Schnee  Atzmännig SSA\n                               ...
# 3  https://www.schweizer-wanderwege.ch/de/wanderv...                  Panorama Trail in Obwalden  Langis\n                                      ...
# 4  https://www.schweizer-wanderwege.ch/de/wanderv...      Schneeschuhwanderung auf den Chasseron  Les Rasses, village\n                         ...
#
#   difficulty_level  duration distance physical_demand ascent descent                                       target_group      season  \
# 0              NaN       NaN       4m            hoch    NaN     NaN  Zyklus 1 (Grundschule / 6 - 9 Jahre alt), Zykl...  ganzjährig
# 1              NaN  6h 45min   11.4km            hoch   720m    720m                                                NaN      Winter
# 2              NaN  1h 40min    4.2km          mittel   140m    510m                                       für Familien      Winter
# 3              NaN  4h 30min   12.3km            hoch   565m    565m                                                NaN      Winter
# 4              NaN  4h 20min     10km            hoch   450m    450m                                                NaN      Winter
#
#   recommended_period
# 0                NaN
# 1    Dezember - März
# 2    Dezember - März
# 3    Dezember - März
# 4    Dezember - März

# %% [markdown]
# ### 3. Remove duplicate routes using the unique URL

# %%
# -----------------------------------------------------------
# Remove duplicate hiking routes based on the URL.
# The URL uniquely identifies a hiking detail page.
# -----------------------------------------------------------
before = len(df)
df = df.drop_duplicates(subset=["url"])
after = len(df)

print("Rows before removing duplicates:", before)
print("Rows after:", after)
# Out:
# Rows before removing duplicates: 375
# Rows after: 375

# %% [markdown]
# ### 4. Convert distance to a numeric float (km)

# %%
# -----------------------------------------------------------
# Convert values like "11km" into the numeric value 11.0
# -----------------------------------------------------------

def parse_distance_km(x):
    """
    Convert strings such as '11km' or '11 km' to a float.
    If the value cannot be parsed, return NaN.
    """
    if pd.isna(x):
        return np.nan

    m = re.match(r"([\d.]+)\s*(km|m)$", str(x).lower())
    if not m:
        return np.nan

    value, unit = m.groups()
    return float(value) / 1000 if unit == "m" else float(value)

df["distance_km"] = df["distance"].apply(parse_distance_km)

df[["distance", "distance_km"]].head()
# Out:
#   distance  distance_km
# 0       4m         0.00
# 1   11.4km        11.40
# 2    4.2km         4.20
# 3   12.3km        12.30
# 4     10km        10.00

# %% [markdown]
# ### 5. Convert duration into total minutes

# %%
# -----------------------------------------------------------
# Convert strings like "3h 15min" into total minutes.
# Example: "3h 15min" → 195 minutes
#          "2h" → 120
#          "45min" → 45
# -----------------------------------------------------------

def duration_to_minutes(x):
    if pd.isna(x):
        return np.nan
    
    text = str(x).lower().replace(" ", "")
    
    # Extract hours and minutes
    hours = 0
    minutes = 0

    h_match = re.search(r"(\d+)h", text)
    m_match = re.search(r"(\d+)min", text)

    if h_match:
        hours = int(h_match.group(1))
    if m_match:
        minutes = int(m_match.group(1))

    total = hours * 60 + minutes
    return total if total > 0 else np.nan

df["duration_min"] = df["duration"].apply(duration_to_minutes)

df[["duration", "duration_min"]].head()
# Out:
#    duration  duration_min
# 0       NaN           NaN
# 1  6h 45min        405.00
# 2  1h 40min        100.00
# 3  4h 30min        270.00
# 4  4h 20min        260.00

# %% [markdown]
# ### 6. Convert ascent & descent into integer meters

# %%
# -----------------------------------------------------------
# Convert values like "310m" into integer values such as 310
# -----------------------------------------------------------

def height_to_m(x):
    if pd.isna(x):
        return np.nan
    match = re.findall(r"\d+", str(x))
    return int(match[0]) if match else np.nan

df["ascent_m"]  = df["ascent"].apply(height_to_m)
df["descent_m"] = df["descent"].apply(height_to_m)

df[["ascent", "ascent_m", "descent", "descent_m"]].head()
# Out:
#   ascent  ascent_m descent  descent_m
# 0    NaN       NaN     NaN        NaN
# 1   720m    720.00    720m     720.00
# 2   140m    140.00    510m     510.00
# 3   565m    565.00    565m     565.00
# 4   450m    450.00    450m     450.00

# %% [markdown]
# ### 7. Split the location field into area, region, and canton

# %%
# -----------------------------------------------------------
# The 'location' field sometimes looks like:
# "Abländschen, Mittelberg — Saanen • BE"
#
# We split this into:
# - area        (left side of —)
# - region      (right side of —)
# - canton      (after the bullet •)
# -----------------------------------------------------------

def extract_canton(loc):
    if pd.isna(loc): return np.nan
    # Entferne Zeilenumbrüche und überflüssige Whitespaces
    loc_clean = ' '.join(str(loc).split())
    parts = loc_clean.split("•")
    return parts[-1].strip() if len(parts) > 1 else np.nan

def extract_region(loc):
    if pd.isna(loc): return np.nan
    loc_clean = ' '.join(str(loc).split())
    left = loc_clean.split("•")[0]
    if "—" in left:
        return left.split("—")[1].strip()
    return left.strip()

def extract_area(loc):
    if pd.isna(loc): return np.nan
    loc_clean = ' '.join(str(loc).split())
    left = loc_clean.split("•")[0]
    if "—" in left:
        return left.split("—")[0].strip()
    return left.strip()

df["canton"] = df["location"].apply(extract_canton)
df["region"] = df["location"].apply(extract_region)

df["area"]   = df["location"].apply(extract_area)

df[["location", "area", "region", "canton"]].head()
# Out:
#                                             location                 area               region canton
# 0                                          Muotathal            Muotathal            Muotathal    NaN
# 1  Urnäsch, Anker\n                              ...       Urnäsch, Anker       Urnäsch, Anker     AR
# 2  Atzmännig SSA\n                               ...        Atzmännig SSA    Atzmännig, Schutt     SG
# 3  Langis\n                                      ...               Langis               Langis     OW
# 4  Les Rasses, village\n                         ...  Les Rasses, village  Les Rasses, village     VD

# %% [markdown]
# ### 8. Encode difficulty & physical demand (categorical → numeric)

# %%
# -----------------------------------------------------------
# Convert categorical difficulty levels to numeric values
# Example: T1→1, T2→2, ..., T6→6
# WICHTIG: difficulty_level bleibt mit T-Präfix (z.B. "T2")
# -----------------------------------------------------------

difficulty_map = {
    "T1": 1, "T2": 2, "T3": 3,
    "T4": 4, "T5": 5, "T6": 6
}

def clean_difficulty_level(x):
    """
    Entfernt Whitespaces, normalisiert auf Großbuchstaben und
    gibt None zurück, wenn kein gültiges T1..T6 vorhanden ist.
    """
    if pd.isna(x):
        return None
    s = re.sub(r'\s+', '', str(x))
    if s == "" or s.lower() == "nan":
        return None
    s = s.upper()
    return s if re.match(r"^T[1-6]$", s) else None

# Anwenden: difficulty_level wird jetzt None statt 'nan'/'NaN' als String
df["difficulty_level"] = df["difficulty_level"].apply(clean_difficulty_level)

# difficulty_num als nullable Integer (pd.NA -> SQL NULL)
df["difficulty_num"] = df["difficulty_level"].map(difficulty_map).astype("Int64")


df[["difficulty_level", "difficulty_num"]].head()
# Out:
#   difficulty_level  difficulty_num
# 0             None            <NA>
# 1             None            <NA>
# 2             None            <NA>
# 3             None            <NA>
# 4             None            <NA>

# %%
# -----------------------------------------------------------
# Convert "leicht/mittel/hoch" to numeric 1/2/3
# -----------------------------------------------------------

physical_demand_map = {"leicht":1, "mittel":2, "hoch":3}

df["physical_demand"] = df["physical_demand"].astype(str).str.lower().str.strip()
df["physical_demand_num"] = df["physical_demand"].map(physical_demand_map)

df[["physical_demand", "physical_demand_num"]].head()
# Out:
#   physical_demand  physical_demand_num
# 0            hoch                 3.00
# 1            hoch                 3.00
# 2          mittel                 2.00
# 3            hoch                 3.00
# 4            hoch                 3.00

# %% [markdown]
# ### 9. Open-Data-Enrichment with longitude & latitude

# %%
import os
import time
import requests
import pandas as pd
import numpy as np

CACHE_FILE = "geocoding_cache.csv"
RATE_LIMIT_SECONDS = 0.25
REQUEST_TIMEOUT_SECONDS = 2


def geocode_osm(place: str):
    """
    Query OpenStreetMap Nominatim API to get latitude and longitude for a place.
    Always prints the final request URL (or a clear message if the request couldn't be built/sent).
    Returns (lat, lon) as floats, or (None, None) if nothing is found / error.
    """
    if pd.isna(place) or str(place).strip() == "":
        print("API Request: (skipped - empty place)")
        return None, None

    url = "https://nominatim.openstreetmap.org/search"
    params = {
        "q": str(place),
        "format": "json",
        "addressdetails": 1,
        "limit": 1,
        "countrycodes": "ch",
    }
    headers = {
        "User-Agent": "SwissHikeGeocoder/1.0 (contact: you@example.com)"
    }

    try:
        # Prepare first so we can ALWAYS print the final URL, even if the request fails.
        req = requests.Request("GET", url, params=params, headers=headers)
        prepped = req.prepare()

        print(f"API Request: {prepped.url}")

        with requests.Session() as s:
            # timeout=2 applies to both connect+read when passed as a single number
            response = s.send(prepped, timeout=REQUEST_TIMEOUT_SECONDS)
            response.raise_for_status()
            data = response.json()

        if not data:
            return None, None

        return float(data[0]["lat"]), float(data[0]["lon"])

    except Exception as e:
        print(f"API Error for place='{place}': {type(e).__name__}: {e}")
        return None, None

    finally:
        time.sleep(RATE_LIMIT_SECONDS)


def ensure_cache_file_exists(cache_file: str = CACHE_FILE):
    if not os.path.exists(cache_file):
        with open(cache_file, "w", encoding="utf-8") as f:
            f.write("url,latitude,longitude\n")


def normalize_cache_file(cache_file: str = CACHE_FILE):
    ensure_cache_file_exists(cache_file)

    cache_df = pd.read_csv(cache_file)

    if cache_df.empty:
        return {}

    cache_df["latitude"] = pd.to_numeric(cache_df["latitude"], errors="coerce")
    cache_df["longitude"] = pd.to_numeric(cache_df["longitude"], errors="coerce")
    cache_df = cache_df.dropna(subset=["url", "latitude", "longitude"])
    cache_df["url"] = cache_df["url"].astype(str)

    cache_df = cache_df.drop_duplicates(subset=["url"], keep="last")
    cache_df.to_csv(cache_file, index=False)

    cache_dict = dict(zip(cache_df["url"], zip(cache_df["latitude"], cache_df["longitude"])))
    print(f"Loaded {len(cache_dict)} cached coordinates (deduplicated)")
    return cache_dict


def get_coordinates(place, identifier, cache_dict):
    if identifier in cache_dict:
        lat, lon = cache_dict[identifier]
        print(f"Found in cache: {place} -> {lat}, {lon}")
        return float(lat), float(lon)

    lat, lon = geocode_osm(place)

    if lat is None or lon is None:
        print(f"Not found: {place}")
        return np.nan, np.nan

    print(f"Geocoded: {place} -> {lat}, {lon}")
    return lat, lon


def append_to_cache(cache_file, identifier, lat, lon):
    if pd.isna(lat) or pd.isna(lon):
        return

    with open(cache_file, "a", encoding="utf-8") as f:
        f.write(f"{identifier},{lat},{lon}\n")
        f.flush()


def geocode_dataframe(df: pd.DataFrame, cache_file: str = CACHE_FILE) -> pd.DataFrame:
    df = df.copy()
    df["latitude"] = np.nan
    df["longitude"] = np.nan

    cache_dict = normalize_cache_file(cache_file)

    for idx, row in df.iterrows():
        place = row.get("area")
        identifier = row.get("url")

        if pd.isna(identifier) or str(identifier).strip() == "":
            lat, lon = geocode_osm(place)
            df.at[idx, "latitude"] = lat if lat is not None else np.nan
            df.at[idx, "longitude"] = lon if lon is not None else np.nan
            continue

        identifier = str(identifier)

        lat, lon = get_coordinates(place, identifier, cache_dict)

        df.at[idx, "latitude"] = lat
        df.at[idx, "longitude"] = lon

        if identifier not in cache_dict and not (pd.isna(lat) or pd.isna(lon)):
            append_to_cache(cache_file, identifier, lat, lon)
            cache_dict[identifier] = (lat, lon)

    normalize_cache_file(cache_file)
    return df


# -----------------------------------------------------------
# Apply geocoding
# -----------------------------------------------------------
df = geocode_dataframe(df)
# Out:
# Loaded 342 cached coordinates (deduplicated)
# Found in cache: Muotathal -> 46.974668, 8.7658029
# Found in cache: Urnäsch, Anker -> 47.3097591, 9.2762871
# API Request: https://nominatim.openstreetmap.org/search?q=Atzm%C3%A4nnig+SSA&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Atzmännig SSA': HTTPError: 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/search?q=Atzm%C3%A4nnig+SSA&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Atzmännig SSA
# Found in cache: Langis -> 46.8929885, 8.1252606
# Found in cache: Les Rasses, village -> 46.8308907, 6.5547359
# Found in cache: Veltheim AG, Bären -> 47.4369232, 8.1474092
# Found in cache: Bibern SH, Dorf -> 47.7722392, 8.6785329
# Found in cache: Spreitenbach -> 47.4182444, 8.3640342
# Found in cache: Anzère, télécabine -> 46.2948177, 7.3949904
# Found in cache: Les Paccots, Les Rosalys -> 46.5174765, 6.9607181
# Found in cache: Zweisimmen, Sparenmoos -> 46.5511623, 7.3396399
# API Request: https://nominatim.openstreetmap.org/search?q=Hoch-Ybrig%2C+Talst.+Laucheren&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Hoch-Ybrig, Talst. Laucheren': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Hoch-Ybrig, Talst. Laucheren
# Found in cache: Obersaxen, Meierhof Post -> 46.7488711, 9.1002856
# Found in cache: Zeihen, Stauftel -> 47.477424, 8.0897368
# Found in cache: Messen, Dorfplatz -> 47.0918287, 7.4475343
# Found in cache: Lamone-Cadempino -> 46.0394453, 8.9322308
# Found in cache: Gruyères -> 49.7106979, 4.6041316
# Found in cache: Miécourt -> 47.4270918, 7.1747627
# Found in cache: Huttwil -> 47.1147419, 7.8455436
# Found in cache: Malans GR -> 46.9821456, 9.5761204
# Found in cache: Gresso -> 46.2249288, 8.615729
# Found in cache: Arosa Bärenland -> 46.7868662, 9.6654415
# Found in cache: Münster VS -> 46.4870672, 8.2632237
# Found in cache: Vue des Alpes -> 47.072722, 6.869822
# Found in cache: Sparenmoos -> 46.5511623, 7.3396399
# Found in cache: Basel, Schifflände -> 47.5597838, 7.5882058
# Found in cache: Les Mosses -> 46.3960939, 7.1018391
# Found in cache: Lenzerheide -> 46.7280297, 9.5584408
# Found in cache: Kiental -> 46.5836472, 7.7269443
# API Request: https://nominatim.openstreetmap.org/search?q=Bahnhof+Vernier-Meyrin&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Bahnhof Vernier-Meyrin': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Bahnhof Vernier-Meyrin
# Found in cache: Beinwil am See -> 47.2664506, 8.2027093
# API Request: https://nominatim.openstreetmap.org/search?q=Stn.+Moosfluh&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Stn. Moosfluh': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Stn. Moosfluh
# Found in cache: Stels, Hof de Planis -> 46.965837, 9.7146085
# Found in cache: Rotenboden -> 47.1275781, 9.5387175
# Found in cache: Bargen (SH) -> 47.791799, 8.6102341
# API Request: https://nominatim.openstreetmap.org/search?q=Full%2C+Hst.+Schulweg&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Full, Hst. Schulweg': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Full, Hst. Schulweg
# Found in cache: Münster -> 51.9625101, 7.6251879
# Found in cache: Oberwald -> 46.5328571, 8.3520502
# Found in cache: Wirzweli -> 46.9134569, 8.3668617
# Found in cache: La Givrine -> 46.4545264, 6.1117067
# Found in cache: Ovronnaz, Chevaley -> 46.201571, 7.173975
# Found in cache: St. Antönien -> 46.969739, 9.813468
# Found in cache: Sörenberg -> 46.8221657, 8.0349311
# Found in cache: Preda -> 46.5904281, 9.7739244
# Found in cache: Schwägalp -> 47.256134, 9.3192548
# Found in cache: La Lécherette -> 46.4203898, 7.106108
# Found in cache: Schwarzsee, Gypsera -> 46.6701725, 7.287833
# Found in cache: H. Les Sciernes -> 46.4968808, 7.0350776
# Found in cache: La Manche -> 49.9892202, -2.2384698
# Found in cache: Kleine Scheidegg -> 46.5850987, 7.9608968
# Found in cache: Grächen -> 46.1960178, 7.8421612
# Found in cache: Vättis -> 46.9098162, 9.4415215
# Found in cache: Sparenmoos -> 46.5511623, 7.3396399
# Found in cache: Maran -> 45.7649931, 13.1675011
# Found in cache: Tschentenalp -> 46.4990334, 7.5452815
# API Request: https://nominatim.openstreetmap.org/search?q=Stn.+Tr%C3%BCbsee&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Stn. Trübsee': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Stn. Trübsee
# Found in cache: Veysonnaz, station -> 46.1950739, 7.3410559
# Found in cache: Les Mayens-de-Sion, Ouest -> 46.2021709, 7.3698173
# Found in cache: Blauherd -> 46.0168521, 7.7873632
# Found in cache: Gontenbad -> 47.3319339, 9.3721845
# Found in cache: Zugerberg -> 47.1437602, 8.5337843
# Found in cache: Schwendi -> 48.1756438, 9.9784952
# Found in cache: Aminona -> 46.3314255, 7.5322704
# Found in cache: Les Paccots -> 46.5220308, 6.9465972
# Found in cache: La Corbatière -> 47.0663671, 6.8347807
# Found in cache: Muottas Muragl -> 46.5239561, 9.9098329
# Found in cache: Cancori -> 46.4596559, 8.8991911
# API Request: https://nominatim.openstreetmap.org/search?q=Eggbergen&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Eggbergen': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Eggbergen&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Eggbergen
# Found in cache: La Brévine -> 46.9801928, 6.6070172
# API Request: https://nominatim.openstreetmap.org/search?q=Gurnigel%2C+Wasserscheidi&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Gurnigel, Wasserscheidi': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Gurnigel%2C+Wasserscheidi&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Gurnigel, Wasserscheidi
# Found in cache: Gurnigel, Berghaus -> 46.7335645, 7.453424
# Found in cache: Vorsass -> 46.7015964, 7.7722918
# Found in cache: Riederalp -> 46.3782021, 8.0334815
# API Request: https://nominatim.openstreetmap.org/search?q=La+Douane%2C+Les+Esserts&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='La Douane, Les Esserts': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=La+Douane%2C+Les+Esserts&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: La Douane, Les Esserts
# Found in cache: Alp Sellamatt -> 47.1764433, 9.3002863
# Found in cache: Haldi -> 58.8076697, 22.4657466
# Found in cache: Rigi Kulm -> 47.0567857, 8.4861404
# Found in cache: Arvenbüel -> 47.1474357, 9.1731764
# Found in cache: Hasliberg Reuti -> 46.7326511, 8.2105515
# Found in cache: Le Pré Petitjean -> 48.1010988, 6.9175319
# Found in cache: Törbel -> 46.2385196, 7.851508
# Found in cache: Les Diablerets -> 46.3511021, 7.1566435
# API Request: https://nominatim.openstreetmap.org/search?q=Bahnhof+Tschamut-Selva&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Bahnhof Tschamut-Selva': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Bahnhof+Tschamut-Selva&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Bahnhof Tschamut-Selva
# Found in cache: Grimmialp -> 46.57316, 7.4851984
# API Request: https://nominatim.openstreetmap.org/search?q=Springebode&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Springebode': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Springebode&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Springebode
# Found in cache: Brambrüesch -> 46.8261726, 9.5170869
# Found in cache: Giswil -> 46.838175, 8.1880027
# Found in cache: Lehmen -> 50.2839386, 7.454023
# Found in cache: Lavin -> 46.7678263, 10.1114901
# API Request: https://nominatim.openstreetmap.org/search?q=Segnas%2C+Bahnhof&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Segnas, Bahnhof': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Segnas%2C+Bahnhof&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Segnas, Bahnhof
# Found in cache: Jaunpass, Restaurant -> 46.591426, 7.33747
# Found in cache: Ruogig -> 46.903213, 8.6879629
# Found in cache: Mägisalp -> 46.7498245, 8.2363643
# Found in cache: St. Luc, Tignousa -> 46.2284033, 7.6110587
# Found in cache: Beurnevésin, poste -> 47.4922216, 7.1356228
# Found in cache: Langwies -> 46.5124342, 16.9303859
# Found in cache: Weissenstein -> 58.8869266, 25.5699121
# Found in cache: Avers, Juppa -> 46.4523137, 9.5484153
# Found in cache: Realp -> 46.5988457, 8.5020509
# Found in cache: Col des Etroits -> 46.8298657, 6.4950363
# Found in cache: Tignousa -> 46.2284033, 7.6110587
# Found in cache: Adelboden -> 46.4927213, 7.5587618
# Found in cache: Allières -> 43.0361187, 1.3662951
# Found in cache: Mont-Soleil -> 47.1657807, 6.9893661
# Found in cache: St-Martin VS -> 46.1733718, 7.4421788
# Found in cache: Engelberg -> 46.8223497, 8.4043996
# Found in cache: Grächen, Post -> 46.1949266, 7.8383626
# Found in cache: Arosa, Prätschli -> 46.783882, 9.679442
# Found in cache: Arosa, Prätschli -> 46.783882, 9.679442
# Found in cache: Tschiertschen, Waldstafel -> 46.806546, 9.5977001
# Found in cache: Braunwald -> 46.9392639, 8.9984978
# Found in cache: Pesciüm -> 46.5138878, 8.606985
# Found in cache: Wildhaus -> 47.2033184, 9.3507024
# Found in cache: Hallau, Gemeindehaus -> 47.6975304, 8.4597761
# Found in cache: Mauzes Bergle -> 46.5951301, 7.2828468
# Found in cache: Pré de l'Essert, Pt. 1024 -> 46.6451996, 7.2187275
# Found in cache: Lauenen -> 46.4247066, 7.3223985
# API Request: https://nominatim.openstreetmap.org/search?q=Turbach%2C+Rotengraben&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Turbach, Rotengraben': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Turbach%2C+Rotengraben&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Turbach, Rotengraben
# Found in cache: Weinfelden -> 47.5669187, 9.1097539
# Found in cache: Col des Etroits -> 46.8298657, 6.4950363
# Found in cache: Urnäsch -> 47.3178621, 9.2834506
# API Request: https://nominatim.openstreetmap.org/search?q=H%C3%B6hi+Wispile&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Höhi Wispile': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=H%C3%B6hi+Wispile&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Höhi Wispile
# Found in cache: Betelberg -> 46.4356604, 7.4229011
# Found in cache: Brülisau -> 47.2970696, 9.4561264
# Found in cache: Oberneunforn -> 47.6058883, 8.7678049
# Found in cache: Rothenthurm -> 47.1047258, 8.6748441
# Found in cache: Gimmelwald -> 46.5468623, 7.8940031
# Found in cache: Ischalp -> 46.7863826, 9.832945
# Found in cache: Bettmeralp -> 46.3905924, 8.0627954
# Found in cache: Belalp -> 46.3714358, 7.9724714
# Found in cache: Empächli -> 46.9219717, 9.1542662
# Found in cache: Kartause Ittingen -> 47.5832841, 8.8658328
# API Request: https://nominatim.openstreetmap.org/search?q=Chavanne-de-Bogis&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Chavanne-de-Bogis': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Chavanne-de-Bogis&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Chavanne-de-Bogis
# Found in cache: Flumserberg, Mittenwald -> 47.0900578, 9.2979714
# Found in cache: Wil AG -> 47.5609977, 8.1519962
# Found in cache: Unteriberg, Guggelstrasse -> 47.0580562, 8.7993113
# Found in cache: Beatenberg Vorsass -> 46.7015964, 7.7722918
# Found in cache: St-Blaise -> 50.3523312, -4.725889
# Found in cache: Lenk, Metschbahnen -> 46.4419584, 7.456698
# Found in cache: Frieswil -> 46.9950916, 7.2850597
# API Request: https://nominatim.openstreetmap.org/search?q=Wolhusen%2C+Neuemsern-Rossei&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Wolhusen, Neuemsern-Rossei': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Wolhusen%2C+Neuemsern-Rossei&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Wolhusen, Neuemsern-Rossei
# Found in cache: Zermatt -> 46.0212076, 7.749254
# Found in cache: Brülisau -> 47.2970696, 9.4561264
# Found in cache: Col des Mosses -> 46.3989758, 7.1026303
# Found in cache: Mendrisio -> 45.8709661, 8.9875293
# Found in cache: Oberberg St. Karl -> 46.9999576, 8.7202102
# Found in cache: La Brévine -> 46.9801928, 6.6070172
# Found in cache: Obersaxen, Affeier Dorf -> 46.7563393, 9.1198528
# Found in cache: Wengen -> 46.6577188, 11.9243258
# Found in cache: Münsingen -> 46.8739775, 7.5631943
# Found in cache: Tegerfelden, Hochbrücke -> 47.5608453, 8.2868629
# Found in cache: Pontresina -> 46.489993, 9.9042965
# Found in cache: Felskinn -> 46.0688082, 7.9156999
# Found in cache: Hemberg -> 47.3004656, 9.1756588
# Found in cache: Laufenburg -> 47.5671976, 8.0599414
# Found in cache: Le Noirmont -> 46.4841774, 6.1157508
# Found in cache: Untergrenchenberg -> 47.2214876, 7.3810915
# Found in cache: Blatten -> 46.4436311, 7.856841
# Found in cache: Flesche -> 46.3415147, 8.001603
# Found in cache: Sunnegga -> 46.0171665, 7.7697586
# Found in cache: Gadenstatt -> 47.002541, 8.0352078
# Found in cache: Rossberg -> 47.4627404, 8.7142478
# Found in cache: Rosswald -> 50.2047485, 17.689208
# Found in cache: Melchsee-Frutt -> 46.7741051, 8.2695375
# Found in cache: Melchsee-Frutt -> 46.7741051, 8.2695375
# API Request: https://nominatim.openstreetmap.org/search?q=Hoch-Ybrig%2C+Talst.+Weglosen&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Hoch-Ybrig, Talst. Weglosen': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Hoch-Ybrig%2C+Talst.+Weglosen&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Hoch-Ybrig, Talst. Weglosen
# Found in cache: Sils/Segl Maria, Posta -> 46.4302391, 9.7650386
# Found in cache: Verbier, Crettaz Cô -> 46.0978697, 7.2177319
# Found in cache: Teufenthal AG -> 47.3300709, 8.1152406
# Found in cache: Rodersdorf -> 47.4806046, 7.4566901
# Found in cache: Klewenalp -> 46.9391136, 8.4741614
# Found in cache: Grotzenbühl -> 46.9498003, 8.9943976
# API Request: https://nominatim.openstreetmap.org/search?q=Stn.+Les+T%C3%AAtes&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Stn. Les Têtes': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Stn.+Les+T%C3%AAtes&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Stn. Les Têtes
# Found in cache: Zullwil -> 47.3905084, 7.6000186
# Found in cache: Gais -> 46.8331565, 11.9474837
# Found in cache: Guttet -> 46.3247591, 7.6660092
# Found in cache: Attiswil -> 47.2492334, 7.6133081
# API Request: https://nominatim.openstreetmap.org/search?q=Stn.+Mont-Soleil&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Stn. Mont-Soleil': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Stn.+Mont-Soleil&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Stn. Mont-Soleil
# Found in cache: Saanenmöser -> 46.5144482, 7.3046961
# Found in cache: Gschwantenmad -> 46.6888748, 8.1605699
# Found in cache: Marbach LU, Dorf -> 46.8542515, 7.8997465
# Found in cache: Caslano stazione -> 45.9740071, 8.8796805
# API Request: https://nominatim.openstreetmap.org/search?q=Stn.+Mont+P%C3%A8lerin&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Stn. Mont Pèlerin': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Stn.+Mont+P%C3%A8lerin&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Stn. Mont Pèlerin
# Found in cache: Klosters Platz -> 46.869383, 9.8809843
# Found in cache: Liestal -> 47.4839723, 7.7347783
# API Request: https://nominatim.openstreetmap.org/search?q=Buvette+des+Amis+de+La+Chia&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Buvette des Amis de La Chia': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Buvette+des+Amis+de+La+Chia&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Buvette des Amis de La Chia
# Found in cache: Weissenberge -> 52.6203333, 10.5655511
# Found in cache: Holenstein -> 47.0311004, 9.0771048
# Found in cache: St. Antönien, Rüti -> 46.9722703, 9.831016
# API Request: https://nominatim.openstreetmap.org/search?q=S%C3%B6renberg%2C+Rothornbahn&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Sörenberg, Rothornbahn': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=S%C3%B6renberg%2C+Rothornbahn&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Sörenberg, Rothornbahn
# Found in cache: Gitschenen -> 46.9003648, 8.4986454
# Found in cache: Parsonz -> 46.6100192, 9.57179
# Found in cache: Hildisrieden -> 47.1513607, 8.2266792
# Found in cache: Allaman -> 46.4707776, 6.396174
# Found in cache: Porto Ronco, Crodolo Verbano -> 46.1330818, 8.718797
# Found in cache: Les Rasses, village -> 46.2634222, 6.6313786
# Found in cache: Wildhaus Oberdorf -> 47.1915197, 9.3449151
# Found in cache: La Punt-Chamues-ch -> 46.5788766, 9.9260141
# Found in cache: Schinznach Dorf, Oberdorf -> 47.4404603, 8.1301174
# Found in cache: Münster VS -> 46.4870672, 8.2632237
# Found in cache: Heiligkreuz -> 47.7498564, 10.2832047
# Found in cache: Kandersteg -> 46.4975866, 7.6756638
# API Request: https://nominatim.openstreetmap.org/search?q=Col+de+la+Vue+des+Alpes&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Col de la Vue des Alpes': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Col+de+la+Vue+des+Alpes&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Col de la Vue des Alpes
# Found in cache: Wasserfallen -> 47.3791166, 10.5380805
# Found in cache: Bruzella, Paese -> 45.8817517, 9.0351757
# Found in cache: Rosshäusern -> 46.9343355, 7.2968204
# Found in cache: Villars-sur-Ollon -> 46.2977636, 7.055331
# Found in cache: Les Prés-d'Orvin, Bellevue -> 47.1539506, 7.1764095
# Found in cache: Naturfreundehaus Fronalp -> 47.0712669, 9.0907589
# Found in cache: Obertschappina, Skilift -> 46.6868389, 9.3737251
# Found in cache: Lohn GR, Dorf -> 46.6503991, 9.4249992
# Found in cache: Gais -> 46.8331565, 11.9474837
# Found in cache: Col du Marchairuz -> 46.5527909, 6.2502869
# API Request: https://nominatim.openstreetmap.org/search?q=Mostelberg%2C+Bergstation&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Mostelberg, Bergstation': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Mostelberg%2C+Bergstation&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Mostelberg, Bergstation
# Found in cache: Gspon -> 46.225128, 7.9027064
# API Request: https://nominatim.openstreetmap.org/search?q=Col-du-Pillon%2C+Glacier+3000&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Col-du-Pillon, Glacier 3000': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Col-du-Pillon%2C+Glacier+3000&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Col-du-Pillon, Glacier 3000
# Found in cache: Dürrenroth -> 47.0902206, 7.7895896
# Found in cache: Niederscherli -> 46.8850228, 7.3893334
# Found in cache: Morteratsch -> 46.4507365, 9.940432
# Found in cache: Andermatt, Brücke -> 46.6339543, 8.59758
# Found in cache: Vnà, Jalmèr -> 46.8425985, 10.367305
# API Request: https://nominatim.openstreetmap.org/search?q=Morthey%2C+centre&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Morthey, centre': HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://nominatim.openstreetmap.org/search?q=Morthey%2C+centre&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Morthey, centre
# Found in cache: Turren -> 46.7895714, 8.1324548
# Found in cache: Nuglar, Dorfplatz -> 47.4713252, 7.6924647
# Found in cache: Gerolfingen -> 49.0538498, 10.5131619
# Found in cache: Alp Darlux -> 46.6233562, 9.7756677
# Found in cache: First (Grindelwald) -> 46.6504815, 8.0650733
# Found in cache: Eigenthal, Talboden -> 47.0067447, 8.2194961
# Found in cache: Visperterminen, Busterminal -> 46.2581303, 7.9029134
# Found in cache: Hofstetten SO, Unterdorf -> 47.4769528, 7.5119931
# Found in cache: Chevroux, port -> 46.8923736, 6.9028433
# Found in cache: Dotzigen -> 47.1197383, 7.341198
# Found in cache: Aarberg -> 47.0443346, 7.2753004
# Found in cache: Biel / Bienne -> 47.1402077, 7.2439029
# Found in cache: Käserstatt -> 46.7568336, 8.2212269
# Found in cache: Selamatt -> 47.1783094, 9.3002815
# Found in cache: Château-de-Chillon -> 46.4142394, 6.9276018
# Found in cache: Rüeggisberg, Post -> 46.8214018, 7.4390291
# Found in cache: Linden, Dorf -> 46.9528755, 7.6820339
# Found in cache: Neuchâtel -> 46.9895828, 6.9292641
# Found in cache: Grimentz, pl. du Mélèze -> 46.178319, 7.5761041
# Found in cache: Habstetten, Rössli -> 46.9847012, 7.4984431
# Found in cache: Olten -> 47.3496571, 7.903787
# Found in cache: Brunni -> 47.0425291, 8.7017635
# Found in cache: Andiast, posta -> 46.7178166, 9.1740439
# Found in cache: La Valsainte, Couvent -> 46.6492329, 7.188121
# Found in cache: Bussalp -> 46.6504525, 7.9910449
# Found in cache: Schwägalp, Säntis-Schwebebahn -> 47.2564785, 9.3175958
# Found in cache: Ibergeregg -> 47.0174278, 8.7332101
# Found in cache: Wauwil -> 47.184353, 8.026173
# Found in cache: Vercorin, poste -> 46.2561627, 7.5303311
# Found in cache: La Givrine -> 46.4545264, 6.1117067
# Found in cache: Bellinzona -> 46.1920538, 9.0205888
# Found in cache: Cardada (Funivia) -> 46.1832973, 8.7869458
# Found in cache: Rigi Scheidegg -> 47.0274441, 8.5195668
# Found in cache: Cunter, vischnanca -> 46.6073114, 9.5916286
# Found in cache: Rothenthurm -> 47.1047258, 8.6748441
# Found in cache: Courchapoix, village -> 47.3485085, 7.4570752
# Found in cache: Sattel Mostelberg -> 47.0674696, 8.6498568
# Found in cache: Nessental, Schwendi -> 46.7196064, 8.2901957
# Found in cache: Beatenberg Vorsass -> 46.7015964, 7.7722918
# Found in cache: Gemmipass -> 46.3963126, 7.6114172
# Found in cache: Neuchâtel -> 46.9895828, 6.9292641
# Found in cache: Habergschwänd -> 47.1038587, 9.1267617
# Found in cache: Beromünster, Flecken -> 47.2065627, 8.1924757
# Found in cache: Häggenschwil-Winden -> 47.5038653, 9.3586097
# Found in cache: Chrüzhütte -> 46.8712601, 8.4368696
# Found in cache: Les Haudères, centre -> 46.0809695, 7.5133008
# Found in cache: Le Creux-des-Biches -> 47.2035058, 6.9408552
# Found in cache: Münsterlingen Spital -> 47.6320515, 9.2361096
# Found in cache: Untergrenchenberg -> 47.2214876, 7.3810915
# Found in cache: Chäserrugg -> 47.154808, 9.3127749
# Found in cache: Col des Mosses -> 46.3989758, 7.1026303
# Found in cache: Simplon, Monte Leone -> 46.2457365, 8.0238739
# Found in cache: Boudry Littorail -> 46.9494086, 6.8390014
# Found in cache: Kerns, Post -> 46.9007819, 8.2753587
# Found in cache: Hemberg -> 47.3004656, 9.1756588
# Found in cache: Schönried -> 46.5043881, 7.2908891
# Found in cache: Davos Laret, Landhaus -> 46.8397431, 9.8706715
# Found in cache: Vella, Sumsiaras -> 46.7156095, 9.1716617
# Found in cache: Bürchen, Ronalp -> 46.2780869, 7.8239271
# Found in cache: Col du Pillon -> 46.3534286, 7.2045971
# Found in cache: Sörenberg, Post -> 46.8218299, 8.0345661
# API Request: https://nominatim.openstreetmap.org/search?q=Mittel+Arni&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Mittel Arni': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Mittel Arni
# Found in cache: Dalpe, Villaggio -> 46.4742811, 8.775237
# Found in cache: Ufhusen, Käserei Dorf -> 47.1168914, 7.8965101
# Found in cache: Frenkendorf-Füllinsdorf -> 47.501507, 7.7192231
# Found in cache: Schiltwald, Wendeplatz -> 47.2503681, 8.118666
# Found in cache: St. Moritz Bad, Kath. Kirche -> 46.4885379, 9.8375475
# Found in cache: Glacier du Sex Rouge -> 46.3270296, 7.213774
# Found in cache: Chrindi -> 46.6800407, 7.6002866
# Found in cache: Maur, See -> 47.3393805, 8.6730337
# Found in cache: Madulain -> 46.5868703, 9.9389122
# Found in cache: La Vraconnaz, Les Rochettes -> 46.8459175, 6.4694927
# Found in cache: Ettingen, Dorf -> 47.4835235, 7.5458641
# Found in cache: Etziken, Dorf -> 47.1835715, 7.6472184
# Found in cache: Saas-Almagell, Dorfplatz -> 46.0941767, 7.9576584
# Found in cache: Männlichen -> 46.6181397, 7.9380395
# API Request: https://nominatim.openstreetmap.org/search?q=Croix-des-Ruinettes&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Croix-des-Ruinettes': HTTPError: 403 Client Error: Forbidden for url: https://nominatim.openstreetmap.org/search?q=Croix-des-Ruinettes&format=json&addressdetails=1&limit=1&countrycodes=ch
# Not found: Croix-des-Ruinettes
# Found in cache: Fürenalp -> 46.8013357, 8.4684285
# Found in cache: Courtemaîche -> 47.458606, 7.0467882
# Found in cache: Glattfelden -> 47.559752, 8.5008282
# Found in cache: Bern, Elfenau -> 46.9326712, 7.4655907
# Found in cache: Col de Bretaye -> 46.3218865, 7.073167
# Found in cache: Beatenberg -> 46.6932513, 7.783279
# Found in cache: Les Breuleux -> 47.2115671, 7.0054836
# Found in cache: Parpan, Post -> 46.7602456, 9.5575698
# Found in cache: Boniswil -> 47.3161571, 8.1852511
# Found in cache: Lauchernalp -> 46.4131389, 7.7764321
# Found in cache: Anwil, Dorf -> 47.4504199, 7.9411672
# Found in cache: Wirzweli -> 46.9134569, 8.3668617
# Found in cache: Arosio, Paese -> 46.0483355, 8.8998419
# Found in cache: All'Acqua -> 46.486913, 8.4757373
# Found in cache: Nante -> 47.2186371, -1.5541362
# API Request: https://nominatim.openstreetmap.org/search?q=Mogno%2C+Colonia+Pazzalino&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Mogno, Colonia Pazzalino': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Mogno, Colonia Pazzalino
# API Request: https://nominatim.openstreetmap.org/search?q=Campra%2C+Bivio&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Campra, Bivio': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Campra, Bivio
# Found in cache: Müstair, posta -> 46.6260992, 10.4460358
# Found in cache: Biel (Goms) -> 46.4558889, 8.2166061
# Found in cache: Kreuzboden -> 47.4885416, 7.7273249
# Found in cache: Mittelhäusern -> 46.8761849, 7.36711
# API Request: https://nominatim.openstreetmap.org/search?q=Lauenen+b.+Gstaad%2C+Rohrbr%C3%BCcke&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Lauenen b. Gstaad, Rohrbrücke': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Lauenen b. Gstaad, Rohrbrücke
# Found in cache: Sion -> 46.2311749, 7.3588795
# Found in cache: Muttenz -> 47.525113, 7.6477401
# Found in cache: Intragna -> 45.9941511, 8.572928
# Found in cache: Stein am Rhein -> 47.6597323, 8.8596823
# Found in cache: Riehen -> 47.5816927, 7.6479737
# Found in cache: Thayngen -> 47.7470005, 8.7061689
# Found in cache: Bivio, posta -> 46.4700126, 9.6497525
# Found in cache: Sur, baselgia -> 46.5230901, 9.6314257
# API Request: https://nominatim.openstreetmap.org/search?q=Salouf%2C+scola&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Salouf, scola': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Salouf, scola
# Found in cache: Somtgant -> 46.5868697, 9.5537053
# Found in cache: Leukerbad -> 46.3793158, 7.6267416
# Found in cache: Fribourg/Freiburg Poya -> 46.8150815, 7.1560209
# Found in cache: Niederbauen -> 46.9412638, 8.5430251
# Found in cache: Mägisalp -> 46.7498245, 8.2363643
# Found in cache: Andermatt -> 46.6340499, 8.5948148
# Found in cache: Ostermundigen, Rüti -> 46.9553973, 7.5076343
# Found in cache: Morges -> 46.5093268, 6.498317
# Found in cache: Luzern, Maihof -> 47.0643521, 8.30851
# Found in cache: Notkersegg -> 47.4260321, 9.4099225
# Found in cache: Roveredo GR, Centro -> 46.2395368, 9.1345731
# Found in cache: Nussbaumen TG, Schulhaus -> 47.6251294, 8.8269515
# Found in cache: Dardagny, château -> 46.1942166, 5.995375
# Found in cache: Zollhaus -> 48.0446109, 8.5081226
# Found in cache: Bruzella, Paese -> 45.8817517, 9.0351757
# Found in cache: Chiasso -> 45.8355209, 9.0290169
# Found in cache: Salorino, Municipio -> 45.8712933, 8.9868435
# Found in cache: Stabio, Madonnina -> 45.8434007, 8.9206748
# Found in cache: Scudellate, Paese -> 45.9214898, 9.039342
# Found in cache: Stabio, Dazio Vecchio -> 45.8466909, 8.933933
# Found in cache: Tremona -> 45.8807051, 8.9565873
# Found in cache: Meride, Paese -> 45.8905716, 8.9514637
# Found in cache: Herisau -> 47.38555, 9.2787571
# Found in cache: Chamoson-St-Pierre-de-Clages -> 46.1889951, 7.2408518
# Found in cache: Pully, Chenaulaz -> 46.5269424, 6.672796
# Found in cache: Hindelbank, Post -> 47.0430872, 7.5406257
# Found in cache: Zollikerberg -> 47.3456637, 8.5993998
# Found in cache: Rottenschwil, Hecht -> 47.3189955, 8.3720539
# Found in cache: Val-d'Illiez, Frâchette -> 46.2063027, 6.8739742
# Found in cache: Engstligenalp -> 46.4464835, 7.5648635
# Found in cache: Riggisalp (Bergstation) -> 46.6588976, 7.2937039
# Found in cache: Nods, école -> 47.0985502, 6.3357353
# Found in cache: Häfelfingen, Bad Ramsach -> 47.4062598, 7.8722368
# Found in cache: Hitzkirch, Bahnhof -> 47.2248416, 8.2620093
# Found in cache: Amden, Vorderdorf -> 47.1488317, 9.14823
# Found in cache: Klosters Platz -> 46.869383, 9.8809843
# Found in cache: Rivera-Bironico -> 46.1240899, 8.9249644
# Found in cache: Morgenholz -> 47.1247362, 9.0207363
# Found in cache: Empächli -> 46.9219717, 9.1542662
# Found in cache: Weissenberge -> 52.6203333, 10.5655511
# Found in cache: Mettmen -> 47.1248124, 8.9981412
# API Request: https://nominatim.openstreetmap.org/search?q=Habkern%2C+Lombachalp-Roteschwand&format=json&addressdetails=1&limit=1&countrycodes=ch
# API Error for place='Habkern, Lombachalp-Roteschwand': ReadTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=2)
# Not found: Habkern, Lombachalp-Roteschwand
# Found in cache: Simplon, Monte Leone -> 46.2457365, 8.0238739
# Found in cache: Lenk im Simmental -> 46.4579692, 7.4437345
# Found in cache: Mutta -> 46.70513, 8.9996169
# Loaded 342 cached coordinates (deduplicated)

# %% [markdown]
# ### 10. Save the cleaned dataset

# %%
# -----------------------------------------------------------
# Export the cleaned dataset so it can be used in the next steps
# (EDA, modelling, database storage, etc.)
# -----------------------------------------------------------

# Convert duration_min, ascent_m, and descent_m to integer for cleaner output
# Only convert if the value is not NaN
df["duration_min"] = df["duration_min"].apply(lambda x: int(x) if pd.notna(x) else np.nan)
df["ascent_m"] = df["ascent_m"].apply(lambda x: int(x) if pd.notna(x) else np.nan)
df["descent_m"] = df["descent_m"].apply(lambda x: int(x) if pd.notna(x) else np.nan)

# Bereinige location: entferne Zeilenumbrüche und überflüssige Whitespaces
df["location_clean"] = df["location"].apply(lambda x: ' '.join(str(x).split()) if pd.notna(x) else x)

# Extrahiere Canton aus der bereinigten Location (nach dem • Symbol)
def extract_canton_clean(loc):
    if pd.isna(loc): return np.nan
    if "•" in str(loc):
        return str(loc).split("•")[-1].strip()
    return np.nan

df["canton_clean"] = df["location_clean"].apply(extract_canton_clean)

# Entferne "• Canton" aus location, behalte nur die Ortsnamen
def clean_location_remove_canton(loc):
    if pd.isna(loc): return loc
    if "•" in str(loc):
        return str(loc).split("•")[0].strip()
    return str(loc).strip()

df["location_clean"] = df["location_clean"].apply(clean_location_remove_canton)

# Wähle nur die gewünschten Spalten aus
columns_to_export = [
    "url",
    "title", 
    "location_clean",
    "canton_clean",
    "difficulty_level",
    "difficulty_num",
    "duration_min",
    "distance_km",
    "ascent_m",
    "descent_m",
    "physical_demand",
    "latitude",
    "longitude"
]

df_export = df[columns_to_export]

# Benenne Spalten für sauberes CSV
df_export = df_export.rename(columns={
    "location_clean": "location",
    "canton_clean": "canton"
})

print(f"Prepared {len(df_export)} rows with {len(columns_to_export)} columns for MySQL export")
# Out:
# ✅ Prepared 375 rows with 13 columns for MySQL export

# %% [markdown]
# ### 11. Store data in MySQL database

# %%
# -----------------------------------------------------------
# Write cleaned and enriched data to MySQL using utility function
# Make sure Docker container is running: docker compose up -d
# -----------------------------------------------------------

# Nutze write_to_db() Funktion aus db_utils.py
write_to_db(df_export, table_name='wanderwege', if_exists='replace')

# Verify data was written correctly
from db_utils import read_from_db
verification_df = read_from_db("SELECT COUNT(*) as count FROM wanderwege")
print(f"Verification: {verification_df['count'][0]} rows in database")
# Out:
# ✅ Successfully stored 375 rows in table 'wanderwege'
# ✅ Loaded 1 rows, 1 columns from database
#
# ✓ Verification: 375 rows in database
